# %%
import pandas as pd

# %%
df = pd.read_csv('participants_ext.csv')

# %%
df
# Out:
#    FK_student_nick                                              query  \
# 0       aarriagada                        como construir un automovil
# 1          cduarte                                            soapbox
# 2         abastian                               Crear un auto básico
# 3       ocontreras                         Como construir un automovi
# 4         gcurguan                 Como construir un auto de carreras
# 5           mcarep                  construir automovil derby soapbox
# 6        eespinoza           como construir un automovil de carrerqas
# 7         gandrade   que debe tener mi auto para competir en nascar?
# 8       jfernandez                                                asd
# 9          bcortes                        componentes de un automovil
# 10    nguentalican                        como construir un automovil
# 11          dhofer                 plan basico para construir un auto
# 12       mescobarp                             partes de un automovil
# 13      chenriquez                            construir un automóvil
# 14         lguzman                        como construir un automovil
# 15          jgomez                            roblox como crear autos
# 16         mcatril                     como crear un auto para nazcar
# 17       fcastillo                    diseños basicos de un automovil
# 18      marriagada                        como construir un automovil
# 19        nhuaquil               pasos basicos para construir un auto
# 20         mgatica             Como construir un automovil de carrera
# 21        rfuentes                  pasos para construir un automovil
# 22        jbarriap               como hace un auto en chile en python
# 23       mgallardo             carateristicas necesarias para un auto
# 24        ahidalgo  diseños basicos para la construccion de un aut...
# 25     ehernandesp  como hacer un auto para carreras de derby de s...
# 26       jgonzalez                                   soapbox carreras
# 27         scortez                        como construir un automovil
# 28       falvarado                       arquitectura de un automovil
# 29          aduque                                      autos soapbox
#
#                                              snippet1  \
# 0   Cómo construir un auto deportivo con poco dine...
# 1   Soapbox is a Chrome extension that enables any...
# 2   This feature is not available right now. Pleas...
# 3   Construir un motor de automóvil desde cero, ll...
# 4   QUIERES FORMAR PARTE DE LA MEJOR NETWORK DE YO...
# 5   Fácil Soap Box Derby coche construir Estas ins...
# 6   Construye un automóvil de carreras casero y se...
# 7   Están preparados para competir más de 500 mill...
# 8   Anchorage School District website accessibilit...
# 9   El primer viaje largo en un automóvil lo reali...
# 10  Cómo construir un auto deportivo con poco dine...
# 11  Cómo construir un go kart. En este artículo: P...
# 12  Chasis Chasis de un automóvil. Constituye la e...
# 13  La fabricación de automóviles se refiere a la ...
# 14  Cómo construir un auto deportivo con poco dine...
# 15  Como CREAR TU PROPIO COCHE en ROBLOX muy FACIL...
# 16  La tecnología de innovación de los últimos año...
# 17  El término automóvil (del griego auto, "por sí...
# 18  Cómo construir un auto deportivo con poco dine...
# 19  Guía paso a paso para construir tu propio auto...
# 20  Construye un automóvil de carreras casero y se...
# 21  Los 8 pasos esenciales para crear un auto El p...
# 22  Stack Overflow en español es un sitio de pregu...
# 23  La siguiente figura resume rápidamente la func...
# 24  Durante años el chasis tal y como se ha explic...
# 25  Inspírate para Red Bull Soapbox Race con 10 au...
# 26  Una curiosa y bizarra carrera se desarrolla en...
# 27  Cómo construir un auto deportivo con poco dine...
# 28  La relación entre automóviles y arquitectura n...
# 29  Encuentra el Seguro Obligatorio Automotriz SOA...
#
#                                              snippet2  \
# 0   Construir un motor de automóvil desde cero, ll...
# 1   SoapBox is an app designed to help managers ha...
# 2   PARA HACER CAPAS MIRA EL Anexo a Curso de Auto...
# 3   Cómo construir un auto deportivo con poco dine...
# 4   Un auto de carrera puede ser un juego o un obj...
# 5   Sobre soap box derby de coches Soap box derby ...
# 6   Un auto de carrera puede ser un juego o un obj...
# 7   Hay una frase muy importante en estados Unidos...
# 8   Tip: Incorrect ASD file association errors can...
# 9   COMPONENTES DE UN AUTOMOVIL 1. PistónFoto de u...
# 10  Construir un motor de automóvil desde cero, ll...
# 11  El mejor programa gratuito para diseñar modelo...
# 12  Los frenos de un auto son una de las partes de...
# 13  Cómo construir un auto deportivo con poco dine...
# 14  Construir un motor de automóvil desde cero, ll...
# 15  This feature is not available right now. Pleas...
# 16  Hola amigos en este vídeo vamos a hacer un car...
# 17  Te mostramos cómo realizar el mantenimiento bá...
# 18  Construir un motor de automóvil desde cero, ll...
# 19  Unas enormes bovinas de acero, con un peso de ...
# 20  Un auto de carrera puede ser un juego o un obj...
# 21  Bueno, si eres del club de los de "poca pasta ...
# 22  Una pareja de triples comillas también permite...
# 23  Para aprovechar tanto las semiondas positivas ...
# 24  Para nuestro caso de estudio, el proyecto arqu...
# 25  Cómo hacer un carro de plataforma improvisada....
# 26  Red Bull Soap Box Car Race, Bergen 2013 Rolf R...
# 27  Construir un motor de automóvil desde cero, ll...
# 28  Así la Municipalidad de Miraflores pondría a r...
# 29  Need for Speed World Online en 3DJuegos: Bueno...
#
#                                              snippet3   sum_cos  MMR_score
# 0   Relájate y disfruta en HD del proceso de ensam...  0.090246  -0.013984
# 1   A soapbox is a raised platform on which one st...  0.300216  -0.004925
# 2   Crear un diagrama de flujo. En el menú Archivo...  0.011189   0.027738
# 3   Fases. Antes de producir un vehículo, ha de co...  0.079059   0.000189
# 4   UN COCHE DE CARRERAS DEFINICIÓN DEL PROYECTO. ...  0.144053  -0.031535
# 5   3rd Annual Nevada City Soap Box Derby. 3rd Ann...  0.423954  -0.023827
# 6   Estudiantes de la Universidad Politécnica Sale...  0.136630  -0.068315
# 7   NASCAR hace referencia a las siglas en inglés ...  0.195299  -0.020022
# 8   Definición de ASD en el Diccionario de español...  0.088782   0.003169
# 9   Curso Mecánica: Experto en Autopartes | Compon...  0.058460   0.024384
# 10  Relájate y disfruta en HD del proceso de ensam...  0.090246  -0.013984
# 11  Si te dedicas a las ventas y te gustaría ser u...  0.042380   0.029851
# 12  Partes de un automóvil. El automóvil es un med...  0.142349  -0.024612
# 13  Nicolas-Joseph Cugnot (1725-1804), , escritor ...  0.026494   0.018897
# 14  Relájate y disfruta en HD del proceso de ensam...  0.097056  -0.017389
# 15  Como usar auto clicker para Roblox. Distintas ...  0.136133   0.016462
# 16  La tecnología de innovación de los últimos año...  1.000000  -0.500000
# 17  Hoy voy a compartir con uds. la forma de model...  0.051992  -0.025996
# 18  Relájate y disfruta en HD del proceso de ensam...  0.090246  -0.013984
# 19  Cómo construir un carro de LEGO. Hay muchas ma...  0.052547   0.018199
# 20  Estudiantes de la Universidad Politécnica Sale...  0.087386   0.028653
# 21  Cómo se fabrica un coche, en cuatro pasos. Rep...  0.222451  -0.013715
# 22  Mi padre es discapacitado 100% y esta en trami...  0.114467   0.042296
# 23  Poco antes del patinaje ya la batería a duras ...  0.145326  -0.072663
# 24  Muy interesante la construcción y cuidado de u...  0.047260  -0.012483
# 25  Los carros que hayan sido seleccionados para c...  0.073828   0.043221
# 26  Bueno, incluso bajo su perfil más complejo, el...  0.071738   0.000403
# 27  Relájate y disfruta en HD del proceso de ensam...  0.090246  -0.013984
# 28  Sin duda el automóvil es una pieza clave en la...  0.082859   0.011627
# 29  El SOAP, o Seguro Obligatorio de Accidentes Pe...  0.227172  -0.113586

# %%
from gensim.models import Word2Vec

# %% [markdown]
# Se definen 3 nuevos modelos, A o estandar, B con min_count de 8 considerando el contexto y C con min_count de 15 para tener la mitad de palabras que B.
#
# El modelo 0, es igual al modelo C, solo que sin los ultimos cambios del corpus_builder
#
# Se utilizaran las consultas: 0, 1, 2, 4, 5, 11, 12, 15, 19, 23, 26, 28 y 29

# %%
last_w = ['automovil', 'soapbox', 'básico', 'carreras', 'soapbox', 'auto', 'automovil', 'autos', 'auto',
         'auto', 'carreras', 'automovil', 'soapbox']

# %%
#df

# %%
modelA = Word2Vec.load('modelA/word2vec.modelA')
modelB = Word2Vec.load('modelB/word2vec.modelB')
modelC = Word2Vec.load('modelC/word2vec.modelC')

# %%
from metrics import sum_cos_df

# %%
#query_0 = sum_cos_df(modelC, df, user_id=5,size=50) #0, 1, 2, 4, 5, 11, 12, 15, 19, 23, 26, 28 y 29
#query_0.to_csv('modelC/query_05.csv', index=False)

# %%
test_df = pd.read_csv('modelA/query_12.csv')

# %%
test_df
# Out:
#          word_added                                                 s1  \
# 0       principales  En él están comprendidos los circuitos de ence...
# 1          gasolina  Suele denominarse tapa de cilindros porque es ...
# 2           motores  Una guía rápida y fácil para explicar todas es...
# 3         elementos  Las ruedas son los elementos sobre los que se ...
# 4             todas  Partes de un coche Motor Neumáticos Chasis Car...
# 5          conjunto  No existe cuando forma un solo conjunto el mot...
# 6            chasis  El freno de tambor es un dispositivo que reali...
# 7            además  Partes de un automóvil . El motor. ... Es más ...
# 8     mantenimiento  El automóvil está formado por las siguientes p...
# 9        esenciales  Los frenos de disco usan un disco giratorio, q...
# 10           dentro  Tablero de instrumentos: se sitúa debajo del p...
# 11            decir  Partes de un coche Motor Neumáticos Chasis Car...
# 12            mismo  El chasis es el esqueleto de un auto. Puede se...
# 13           frenos  El freno de tambor está formado por: el tambor...
# 14           través  Su misión es orientar las ruedas directrices (...
# 15       combustión  Pedales o mandos de pie. El Acelerador: se acc...
# 16         material  El Automóvil, Concepto, Evolución Histórica, D...
# 17   funcionamiento  @juangangelEl primer automóvil con motor de co...
# 18      información  Chasis. El chasis es el esqueleto de un auto. ...
# 19         realizar  El automóvil utiliza distintos sistemas que fu...
# 20             aire  Partes y funcionamiento del aire acondicionado...
# 21        dirección  Partes del sistema de dirección. El sistema de...
# 22        necesario  Descubre las partes de un coche de forma senci...
# 23      combustible  Partes del sistema de alimentación de gasolina...
# 24        cilindros  En los motores de combustión interna tales com...
# 25            vamos  En él están comprendidos los circuitos de ence...
# 26          control  El ECU, conocido también como la Unidad de Con...
# 27         potencia  Pedales o mandos de pie. El Acelerador: se acc...
# 28          posible  Pedales o mandos de pie. El Acelerador: se acc...
# 29           cuenta  Partes de un coche Motor Neumáticos Chasis Car...
# 30           manera  El automóvil utiliza distintos sistemas que fu...
# 31       materiales  Las puertas, el techo y los paneles de la carr...
# 32       necesarios  Chasis. El chasis es el esqueleto de un auto. ...
# 33             casa  @juangangelEl primer automóvil con motor de co...
# 34          general  El chasis es el esqueleto de un auto. Puede se...
# 35        productos  Los instrumentos, medidores, interruptores, la...
# 36           bloque  principal l descarga de bloques l bloques de c...
# 37            medio  El chasis es el esqueleto de un auto. Puede se...
# 38  características  El VIN es el Número de Identificación Vehicula...
# 39         aprender  El chasis es el esqueleto de un auto. Puede se...
# 40             bien  El VIN es el Número de Identificación Vehicula...
# 41      fabricación  La fabricación de automóviles se refiere a la ...
# 42            nuevo  El VIN es el Número de Identificación Vehicula...
# 43            cosas  El VIN es el Número de Identificación Vehicula...
# 44          energía  El conjunto de componentes del automóvil que u...
# 45        cualquier  @juangangelEl primer automóvil con motor de co...
# 46            ayuda  La suspensión consta de un conjunto de piezas ...
# 47       diferentes  Pedales o mandos de pie. El Acelerador: se acc...
# 48          permite  El motor es el corazón de un auto, es el eleme...
# 49           tiempo  Ahora es el momento de profundizar en la mater...
#
#                                                    s2  \
# 0   Cada coche consta de un motor y gran parte de ...
# 1   https://capacitateparaelempleo.orgLink origina...
# 2   Cuáles son las partes del motor de un coche. A...
# 3   Generalmente se utilizan elementos como resort...
# 4   El chasis es el esqueleto de un auto. Puede se...
# 5   El chasis es el esqueleto de un auto. Puede se...
# 6   Descubre cómo está hecho el chasis de un carro...
# 7   Partes de un coche Motor Neumáticos Chasis Car...
# 8   En este artículo se explican estos mantenimien...
# 9   En ese sentido, la Dirección General de Tráfic...
# 10  Partes de un coche Motor Neumáticos Chasis Car...
# 11  10 partes importantes de un automóvil mecánico...
# 12  @juangangelEl primer automóvil con motor de co...
# 13  ¿Cuáles son las partes de un sistema de frenos...
# 14  El conjunto de componentes del automóvil que u...
# 15  La división primera y fundamental de un motor ...
# 16  Las puertas, el techo y los paneles de la carr...
# 17  Su misión es orientar las ruedas directrices (...
# 18  Descubre las partes de un coche de forma senci...
# 19  La dirección funciona mediante el giro de las ...
# 20  Sistema de aire acondicionado standar para veh...
# 21  La historia de la dirección discurre paralela ...
# 22  El chasis es el esqueleto de un auto. Puede se...
# 23  La bomba empuja la gasolina hacia el líneas de...
# 24  El bloque del motor y los cilindros El bloque ...
# 25  Partes de un coche Motor Neumáticos Chasis Car...
# 26  Su misión es orientar las ruedas directrices (...
# 27  El VIN es el Número de Identificación Vehicula...
# 28  El chasis es el esqueleto de un auto. Puede se...
# 29  Conducir un auto, mecánico o automático, no es...
# 30  Cada coche consta de un motor y gran parte de ...
# 31  Materiales utilizados en la carrocería del aut...
# 32  Partes de un coche Motor Neumáticos Chasis Car...
# 33  El chasis es el esqueleto de un auto. Puede se...
# 34  En él están comprendidos los circuitos de ence...
# 35  @juangangelEl primer automóvil con motor de co...
# 36  La tapa de cilindros es la parte superior del ...
# 37  En esta página puedes ver las diferentes parte...
# 38  El motor, las ruedas, los frenos, las ventanas...
# 39  @juangangelEl primer automóvil con motor de co...
# 40  @juangangelEl primer automóvil con motor de co...
# 41  La fabricación de un coche se divide, fundamen...
# 42  @juangangelEl primer automóvil con motor de co...
# 43  Descubre las partes de un coche de forma senci...
# 44  Que partes de un automóvil emplean energía par...
# 45  Partes de un amortiguador. Un amortiguador es ...
# 46  @juangangelEl primer automóvil con motor de co...
# 47  El chasis es el esqueleto de un auto. Puede se...
# 48  Descubre las partes de un coche de forma senci...
# 49  los automoviles modernos están compuestos por ...
#
#                                                    s3  similarity_w   sum_cos
# 0   El conjunto de componentes del automóvil que u...      0.999048  0.062153
# 1   Es el depósito o alojamiento de combustible, t...      0.998833  0.056927
# 2   Cómo identificar las partes del motor de un co...      0.998812  0.222042
# 3   El conjunto de componentes del automóvil que u...      0.998788  0.334127
# 4   Partes de un auto y sus funciones El motor. Ca...      0.998783  0.342168
# 5   Es el conjunto de sistemas que interactuando e...      0.998773  0.227495
# 6   Las partes de un chasis Primordialmente, el ch...      0.998725  0.141860
# 7   El ECU, conocido también como la Unidad de Con...      0.998673  0.282077
# 8   Deben revisarse siempre que el vehículo entre ...      0.998659  0.122765
# 9   Como la mayoría de los automóviles que se fabr...      0.998619  0.051466
# 10  @juangangelEl primer automóvil con motor de co...      0.998600  0.089707
# 11  La suspensión del automóvil está formada por l...      0.998582  0.140782
# 12  los automoviles modernos están compuestos por ...      0.998573  0.042702
# 13  Partes del sistema de frenos. El sistema de fr...      0.998558  0.185947
# 14  El chasis es el esqueleto de un auto. Puede se...      0.998545  0.227988
# 15  Motor de combustión interna y sus partes El bl...      0.998524  0.307501
# 16  En promedio un auto puede contener 1,350 kilóg...      0.998523  0.241721
# 17  Partes de un auto y sus funciones El motor. Ca...      0.998480  0.130836
# 18  Anatomía de un automóvil: vehículo de carreter...      0.998446  0.137365
# 19  El chasis es el esqueleto de un auto. Puede se...      0.998439  0.061258
# 20  De uno a tres cilindros, construidos en duralu...      0.998437  0.219246
# 21  0 Comentarios. La dirección está formada por v...      0.998428  0.468590
# 22  Aparte de los filtros surtidos familiares para...      0.998422  0.126984
# 23  Especialista de la marca DFSK Glory menciona l...      0.998421  0.256910
# 24  Circuito de encendido: se encarga de producir ...      0.998397  0.191049
# 25  Partes de un coche Motor Neumáticos Chasis Car...      0.998390  1.000000
# 26  Los cambios se colocan en el centro del vehícu...      0.998373  0.059842
# 27  Las partes de un automovil. los automoviles mo...      0.998370  0.091056
# 28  Una de las partes más visibles del coche es el...      0.998369  0.048543
# 29  Especialista de la marca DFSK Glory menciona l...      0.998343  0.041174
# 30  Chasis. El chasis es el esqueleto de un auto. ...      0.998325  0.000000
# 31  En promedio un auto puede contener 1,350 kilóg...      0.998321  0.352232
# 32  Aparte de los filtros surtidos familiares para...      0.998299  0.151143
# 33  Curso Mecánica: Experto en Autopartes | Compon...      0.998296  0.024613
# 34  Pero a pesar de todos los cambios que han teni...      0.998280  0.141040
# 35  Las partes específicas de una línea de producc...      0.998270  0.080080
# 36  Bloque motor de fundición, seccionado (en gris...      0.998269  0.183568
# 37  @juangangelEl primer automóvil con motor de co...      0.998258  0.283268
# 38  Partes principales en vehículos automóviles Es...      0.998255  0.166527
# 39  Cómo aprender sobre las partes de un coche. en...      0.998242  0.000000
# 40  Curso Mecánica: Experto en Autopartes | Compon...      0.998223  0.053888
# 41  Y, la fase final del proceso de producción de ...      0.998217  0.112200
# 42  Curso Mecánica: Experto en Autopartes | Compon...      0.998213  0.053888
# 43  10 partes importantes de un automóvil mecánico...      0.998205  0.099685
# 44  Circuito de carga: es el que responde a la ene...      0.998202  0.131338
# 45  Frenos Manubrio o Volante Faros o Luces Gracia...      0.998191  0.113678
# 46  los automoviles modernos están compuestos por ...      0.998190  0.051645
# 47  Explicación de las diferentes partes de un aut...      0.998178  0.110149
# 48  Parte de un automóvil que permite maniobrarlo ...      0.998172  0.014715
# 49  El tiempo necesario aproximado para el montaje...      0.998168  0.067534
