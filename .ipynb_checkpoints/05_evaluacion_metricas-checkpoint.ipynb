# %% [markdown]
# @eidepozo

# %% [markdown]
# De 05B_participantes:

# %%
import pandas as pd

# %%
df = pd.read_csv('participants_ext.csv')

# %% [markdown]
# Se utilizaran las consultas: 0, 1, 2, 4, 5, 11, 12, 15, 19, 23, 26, 28 y 29 para los tres modelos.

# %%
from gensim.models import Word2Vec

# %%
modelA = Word2Vec.load('modelA/word2vec.modelA')
modelB = Word2Vec.load('modelB/word2vec.modelB')
modelC = Word2Vec.load('modelC/word2vec.modelC')

# %%
file_names = ['00', '01', '02', '04', '05', '11', '12', '15', '19', '23', '26', '28', '29']

# %%
modelA_q = [] # iterable df para cada query
modelB_q = []
modelC_q = []

# %%
for name in file_names:
    modelA_q.append(pd.read_csv('modelA/query_'+name+'.csv'))
    modelB_q.append(pd.read_csv('modelB/query_'+name+'.csv'))
    modelC_q.append(pd.read_csv('modelC/query_'+name+'.csv'))

# %%
last_w = ['automovil', 'soapbox', 'básico', 'carreras', 'soapbox', 'auto', 'automovil', 'autos', 'auto',
         'auto', 'carreras', 'automovil', 'soapbox']
ulast_w = ['automovil', 'soapbox', 'básico', 'carreras', 'auto', 'autos']

# %%
word_added = [] # iterable para evaluar vocabularios post modelo

# %%
for ele in range(len(file_names)):
    aux = pd.concat([modelA_q[ele]['word_added'],
                                 modelB_q[ele]['word_added'], modelC_q[ele]['word_added']], axis=1)
    aux.columns=['model_A', 'model_B', 'model_C']
    word_added.append(aux)

# %%
word_added[0]
# Out:
#             model_A         model_B         model_C
# 0       principales     principales     principales
# 1          gasolina            aire        sistemas
# 2           motores       dirección           parte
# 3         elementos      diferentes        conjunto
# 4             todas         motores       elementos
# 5          conjunto        potencia           decir
# 6            chasis      esenciales          dentro
# 7            además        gasolina        potencia
# 8     mantenimiento   mantenimiento  funcionamiento
# 9        esenciales          chasis          partes
# 10           dentro       elementos            aire
# 11            decir           todas      carrocería
# 12            mismo          dentro          tiempo
# 13           frenos     fabricación         posible
# 14           través       cilindros      esenciales
# 15       combustión  funcionamiento        gasolina
# 16         material        conjunto     combustible
# 17   funcionamiento     combustible   mantenimiento
# 18      información          bloque        funciona
# 19         realizar        sistemas         utiliza
# 20             aire          través         motores
# 21        dirección          manera         volante
# 22        necesario         control          manera
# 23      combustible      combustión       dirección
# 24        cilindros         posible          chasis
# 25            vamos           nuevo     componentes
# 26          control     información         función
# 27         potencia      suspensión          además
# 28          posible            bien         control
# 29           cuenta       cualquier           todas
# 30           manera           mismo          frenos
# 31       materiales         sistema            bien
# 32       necesarios      necesarios      movimiento
# 33             casa             así     fabricación
# 34          general           plano       conductor
# 35        productos        material         conocer
# 36           bloque            hora        vehiculo
# 37            medio          tiempo         muestra
# 38  características       principal            tipo
# 39         aprender       seguridad    arquitectura
# 40             bien        realizar            hora
# 41      fabricación          diseño       productos
# 42            nuevo          cuales           cosas
# 43            cosas         volante         básicas
# 44          energía           mayor            peso
# 45        cualquier         muestra            lado
# 46            ayuda          cuenta         medidas
# 47       diferentes         energía            debe
# 48          permite      movimiento           capaz
# 49           tiempo          frenos          equipo

# %%
#https://stackoverflow.com/questions/26977076/pandas-unique-values-multiple-columns
    
unique = list(pd.unique(word_added[0][['model_A', 'model_B', 'model_C']].values.ravel('K')))

# %%
unique_df = pd.DataFrame(unique, columns=['word'])

# %%
unique_df['model_A'] = unique_df['word'].isin(word_added[0]['model_A'])
unique_df['model_B'] = unique_df['word'].isin(word_added[0]['model_B'])
unique_df['model_C'] = unique_df['word'].isin(word_added[0]['model_C'])

# %%
unique_df
# Out:
#            word  model_A  model_B  model_C
# 0   principales     True     True     True
# 1      gasolina     True     True     True
# 2       motores     True     True     True
# 3     elementos     True     True     True
# 4         todas     True     True     True
# ..          ...      ...      ...      ...
# 78         lado    False    False     True
# 79      medidas    False    False     True
# 80         debe    False    False     True
# 81        capaz    False    False     True
# 82       equipo    False    False     True
#
# [83 rows x 4 columns]

# %%
#unique_df[unique_df['model_A'] == False]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ref = {
    0: 0,
    1: 1,
    2: 2,
    3: 4,
    4: 5,
    5: 11,
    6: 12,
    7: 15,
    8: 19,
    9: 23,
    10: 26,
    11: 28,
    12: 29
}

# %%
def query_scatter_plot(index, user_id, df): # al tratar con df debe indicarse el usuario puntual
    plot_0 = modelA_q[index].plot.scatter(x='similarity_w', y='sum_cos', title=df.iloc[user_id][1], figsize=(10,5))
    modelB_q[index].plot.scatter(x='similarity_w', y='sum_cos', ax=plot_0, color='green')
    modelC_q[index].plot.scatter(x='similarity_w', y='sum_cos', ax=plot_0, color='orange')
    plot_0.axhline(y=df.iloc[user_id][5], color ='r', label= df.iloc[user_id][5])
    plot_0.legend()

# %%
keylist = list(ref)

# %%
query_scatter_plot(keylist[0],ref[0], df)

# %%
len(modelA_q[0][modelA_q[0]['sum_cos']<= df.iloc[0][5]].index)/len(modelA_q[0].index)*100
# Out:
# 76.0

# %%
under_margin = pd.DataFrame()

# %%
for i in range(len(file_names)):
    a = len(modelA_q[i][modelA_q[i]['sum_cos']<= df.iloc[ref[i]][5]].index)/len(modelA_q[i].index)*100
    b = len(modelB_q[i][modelB_q[i]['sum_cos']<= df.iloc[ref[i]][5]].index)/len(modelB_q[i].index)*100
    c = len(modelC_q[i][modelC_q[i]['sum_cos']<= df.iloc[ref[i]][5]].index)/len(modelC_q[i].index)*100
    l = [df.iloc[ref[i]][5], a,b,c]
    auxdf = pd.DataFrame([l])
    under_margin = pd.concat([under_margin, auxdf])

# %%
under_margin = under_margin.rename(columns={0: "sum_cos_ori", 1: "modelA", 2: "modelB", 3: 'modelC'}).reset_index(drop=True)

# %%
under_margin
# Out:
#     sum_cos_ori  modelA  modelB  modelC
# 0      0.090246    76.0    76.0    78.0
# 1      0.300216    50.0    58.0    52.0
# 2      0.011189    10.0     8.0     8.0
# 3      0.144053    86.0    82.0    92.0
# 4      0.423954    82.0    82.0    78.0
# 5      0.042380    32.0    24.0    24.0
# 6      0.142349    62.0    68.0    56.0
# 7      0.136133    86.0    92.0    82.0
# 8      0.052547    30.0    32.0    40.0
# 9      0.145326    70.0    80.0    76.0
# 10     0.071738    16.0     8.0    12.0
# 11     0.082859    36.0    50.0    56.0
# 12     0.227172    36.0    54.0    48.0

# %%
under_margin.describe()
# Out:
#        sum_cos_ori     modelA     modelB     modelC
# count    13.000000  13.000000  13.000000  13.000000
# mean      0.143859  51.692308  54.923077  54.000000
# std       0.114724  26.880552  28.874618  27.215192
# min       0.011189  10.000000   8.000000   8.000000
# 25%       0.071738  32.000000  32.000000  40.000000
# 50%       0.136133  50.000000  58.000000  56.000000
# 75%       0.145326  76.000000  80.000000  78.000000
# max       0.423954  86.000000  92.000000  92.000000

# %% [markdown]
# En promedio el mejor modelo es el B, conteniendo un 54.9% de los nuevos resultados con una menor o igual diversidad a la consulta original.
