# %% [markdown]
# @eidepozo

# %% [markdown]
# ### Extracción del dataset
#
# Se adapto a una versión local debido a problemas con la conexión al servidor

# %%
import pymysql
import pandas as pd

# %%
query1 = "SELECT date_executed, FK_challenge_id_number, FK_student_nick,id_number,query,snippet \
        FROM Students_query\
        INNER JOIN Students_queries_results ON FK_student_query_id_number = id_number\
        WHERE FK_challenge_id_number = 4 AND FK_student_nick != 'test_student'\
        AND date_executed BETWEEN '2019-04-29 00:00:00' AND '2019-04-29 23:59:59'"

query2 = "SELECT DISTINCT FK_student_nick FROM Students_query\
        WHERE FK_challenge_id_number = 4 \
        AND date_executed BETWEEN '2019-04-29 00:00:00' AND '2019-04-29 23:59:59'\
        AND FK_student_nick != 'test_student'"

# %%
conn = pymysql.connect(host='localhost', user='root',
                       passwd='rotted',db='gonsa2')

data = pd.read_sql(query1, conn)
conn.close()

# %%
data
# Out:
#             date_executed  FK_challenge_id_number FK_student_nick  id_number  \
# 0     2019-04-29 14:42:34                       4      aarriagada         82
# 1     2019-04-29 14:42:34                       4      aarriagada         82
# 2     2019-04-29 14:42:34                       4      aarriagada         82
# 3     2019-04-29 14:42:34                       4      aarriagada         82
# 4     2019-04-29 14:42:34                       4      aarriagada         82
# ...                   ...                     ...             ...        ...
# 16378 2019-04-29 15:41:25                       4          dhofer        705
# 16379 2019-04-29 15:41:25                       4          dhofer        705
# 16380 2019-04-29 15:41:25                       4          dhofer        705
# 16381 2019-04-29 15:41:25                       4          dhofer        705
# 16382 2019-04-29 15:41:25                       4          dhofer        705
#
#                                           query  \
# 0                   como construir un automovil
# 1                   como construir un automovil
# 2                   como construir un automovil
# 3                   como construir un automovil
# 4                   como construir un automovil
# ...                                         ...
# 16378  como hacer un auto para un derby soapbox
# 16379  como hacer un auto para un derby soapbox
# 16380  como hacer un auto para un derby soapbox
# 16381  como hacer un auto para un derby soapbox
# 16382  como hacer un auto para un derby soapbox
#
#                                                  snippet
# 0      Cómo <b>construir</b> un auto deportivo con po...
# 1      <b>Construir</b> un motor de automóvil desde c...
# 2      Relájate y disfruta en HD del proceso de ensam...
# 3      Esto podría ser tan simple <b>como</b> una par...
# 4      Fases. Antes de producir un vehículo, ha de co...
# ...                                                  ...
# 16378  Tengo un <b>derby</b> 2004 y la luz azul del t...
# 16379  La mayoría de los coches <b>derby</b> están di...
# 16380  zapatos gruesa <b>derby</b> suela Marsèll casu...
# 16381  Aquí les dejo un pequeño manual <b>para</b> co...
# 16382  CAMISETA PORTERO JOMA <b>DERBY</b>. 100% Polié...
#
# [16383 rows x 6 columns]

# %%
from bs4 import BeautifulSoup

# %%
data['snippet'] = data['snippet'].map(lambda text: BeautifulSoup(text, 'html.parser').get_text())

# %%
data[:50]
# Out:
#          date_executed  FK_challenge_id_number FK_student_nick  id_number  \
# 0  2019-04-29 14:42:34                       4      aarriagada         82
# 1  2019-04-29 14:42:34                       4      aarriagada         82
# 2  2019-04-29 14:42:34                       4      aarriagada         82
# 3  2019-04-29 14:42:34                       4      aarriagada         82
# 4  2019-04-29 14:42:34                       4      aarriagada         82
# 5  2019-04-29 14:42:34                       4      aarriagada         82
# 6  2019-04-29 14:42:34                       4      aarriagada         82
# 7  2019-04-29 14:42:34                       4      aarriagada         82
# 8  2019-04-29 14:42:34                       4      aarriagada         82
# 9  2019-04-29 14:42:34                       4      aarriagada         82
# 10 2019-04-29 14:42:34                       4      aarriagada         82
# 11 2019-04-29 14:42:34                       4      aarriagada         82
# 12 2019-04-29 14:42:34                       4      aarriagada         82
# 13 2019-04-29 14:42:34                       4      aarriagada         82
# 14 2019-04-29 14:42:34                       4      aarriagada         82
# 15 2019-04-29 14:42:34                       4      aarriagada         82
# 16 2019-04-29 14:42:34                       4      aarriagada         82
# 17 2019-04-29 14:42:34                       4      aarriagada         82
# 18 2019-04-29 14:42:34                       4      aarriagada         82
# 19 2019-04-29 14:42:34                       4      aarriagada         82
# 20 2019-04-29 14:42:34                       4      aarriagada         82
# 21 2019-04-29 14:42:34                       4      aarriagada         82
# 22 2019-04-29 14:42:34                       4      aarriagada         82
# 23 2019-04-29 14:42:34                       4      aarriagada         82
# 24 2019-04-29 14:42:34                       4      aarriagada         82
# 25 2019-04-29 14:42:34                       4      aarriagada         82
# 26 2019-04-29 14:42:34                       4      aarriagada         82
# 27 2019-04-29 14:42:34                       4      aarriagada         82
# 28 2019-04-29 14:42:34                       4      aarriagada         82
# 29 2019-04-29 14:42:34                       4      aarriagada         82
# 30 2019-04-29 14:42:34                       4      aarriagada         82
# 31 2019-04-29 14:42:34                       4      aarriagada         82
# 32 2019-04-29 14:42:34                       4      aarriagada         82
# 33 2019-04-29 14:42:34                       4      aarriagada         82
# 34 2019-04-29 14:42:34                       4      aarriagada         82
# 35 2019-04-29 14:42:34                       4      aarriagada         82
# 36 2019-04-29 14:42:34                       4      aarriagada         82
# 37 2019-04-29 14:42:34                       4      aarriagada         82
# 38 2019-04-29 14:42:34                       4      aarriagada         82
# 39 2019-04-29 14:42:34                       4      aarriagada         82
# 40 2019-04-29 14:42:34                       4      aarriagada         82
# 41 2019-04-29 14:42:34                       4      aarriagada         82
# 42 2019-04-29 14:42:34                       4      aarriagada         82
# 43 2019-04-29 14:42:34                       4      aarriagada         82
# 44 2019-04-29 14:42:34                       4      aarriagada         82
# 45 2019-04-29 14:42:34                       4      aarriagada         82
# 46 2019-04-29 14:42:34                       4      aarriagada         82
# 47 2019-04-29 14:42:34                       4      aarriagada         82
# 48 2019-04-29 14:42:34                       4      aarriagada         82
# 49 2019-04-29 14:42:36                       4      aarriagada         83
#
#                           query  \
# 0   como construir un automovil
# 1   como construir un automovil
# 2   como construir un automovil
# 3   como construir un automovil
# 4   como construir un automovil
# 5   como construir un automovil
# 6   como construir un automovil
# 7   como construir un automovil
# 8   como construir un automovil
# 9   como construir un automovil
# 10  como construir un automovil
# 11  como construir un automovil
# 12  como construir un automovil
# 13  como construir un automovil
# 14  como construir un automovil
# 15  como construir un automovil
# 16  como construir un automovil
# 17  como construir un automovil
# 18  como construir un automovil
# 19  como construir un automovil
# 20  como construir un automovil
# 21  como construir un automovil
# 22  como construir un automovil
# 23  como construir un automovil
# 24  como construir un automovil
# 25  como construir un automovil
# 26  como construir un automovil
# 27  como construir un automovil
# 28  como construir un automovil
# 29  como construir un automovil
# 30  como construir un automovil
# 31  como construir un automovil
# 32  como construir un automovil
# 33  como construir un automovil
# 34  como construir un automovil
# 35  como construir un automovil
# 36  como construir un automovil
# 37  como construir un automovil
# 38  como construir un automovil
# 39  como construir un automovil
# 40  como construir un automovil
# 41  como construir un automovil
# 42  como construir un automovil
# 43  como construir un automovil
# 44  como construir un automovil
# 45  como construir un automovil
# 46  como construir un automovil
# 47  como construir un automovil
# 48  como construir un automovil
# 49  como construir un automovil
#
#                                               snippet
# 0   Cómo construir un auto deportivo con poco dine...
# 1   Construir un motor de automóvil desde cero, ll...
# 2   Relájate y disfruta en HD del proceso de ensam...
# 3   Esto podría ser tan simple como una parte Radi...
# 4   Fases. Antes de producir un vehículo, ha de co...
# 5   Haz un agujero en el centro y añade una varill...
# 6   Cómo construir un compresor de aire de un moto...
# 7   Diviértete con un automóvil de juguete que se ...
# 8   Los automóviles también comienzan sus vidas co...
# 9   Construir un vagón de 3/4 de pulgada de madera...
# 10  Cómo construir un cobertizo para el carro. En ...
# 11  Nicolas-Joseph Cugnot (1725-1804), , escritor ...
# 12  Cómo construir un auto ratonera. En este artíc...
# 13  En general, las camas con forma de automóvil p...
# 14  Un auto de carrera puede ser un juego o un obj...
# 15  COMO SE CONSTRUYE UN AUTOMOVIL. El automóvil s...
# 16  Como hacer un AUTOMOVIL ELECTRICO PARA NIÑOS. ...
# 17  Si estás a punto de construir una entrada para...
# 18  Cómo construir un Automóvil personalizado Onli...
# 19  Volvo piensa vender un XC40 completamente eléc...
# 20  Cómo construir una alarma para tu automóvil. H...
# 21  La fabricación de un coche se divide, fundamen...
# 22  Suele estar construido en diferentes materiale...
# 23  Un automóvil eléctrico que puede remolcar un c...
# 24  Todo indica que un Mustang eléctrico está en l...
# 25  Imágenes de cómo se construye un automóvil des...
# 26  El automóvil puede ser descrito como un vehícu...
# 27  Mejor respuesta: explicate un poco mas. es una...
# 28  Cómo construir un automóvil eléctrico - El ret...
# 29  Cómo construir un compresor de aire de un moto...
# 30  Kia Forte del 2019, un buen automóvil para el ...
# 31  Cómo construir un volante de madera . Quizás s...
# 32  Hello gente, necesito con urgencia , que algui...
# 33  (1725-1804), mecánico, ingeniero militar, escr...
# 34  ¿Cómo se auto-construye un automóvil? Deseo in...
# 35  La compra de Intel a Mobileye afianza a Israel...
# 36  El Fardier, como lo llamó Cugnot, comenzó a ci...
# 37  Un automóvil con energía solar que no comprome...
# 38  Descubre la historia de los carros, su orígen,...
# 39  El Dodge Challenger del 2019 se llevó el máxim...
# 40  Un estudio revela que la marihuana desconcentr...
# 41  Hoy un servidor puede presumir de haber tocado...
# 42  El Fardier, como lo llamó Cugnot, comenzó a ci...
# 43  El Dodge Challenger del 2019 se llevó el máxim...
# 44  Más tarde, se intentó construir un vehiculo mo...
# 45  El Dodge Challenger del 2019 se llevó el máxim...
# 46  Como se crea, se diseña, se fabrica, se vende,...
# 47  Nicolas-Joseph Cugnot (1725-1804), escritor e ...
# 48  Charles Randolph construye un vehículo a vapor...
# 49  Cómo construir un auto deportivo con poco dine...

# %%
df = data['snippet'].drop_duplicates() # una mejor opcion seria eliminar los snippets que se repiten sin dejar copias
df
# Out:
# 0        Cómo construir un auto deportivo con poco dine...
# 1        Construir un motor de automóvil desde cero, ll...
# 2        Relájate y disfruta en HD del proceso de ensam...
# 3        Esto podría ser tan simple como una parte Radi...
# 4        Fases. Antes de producir un vehículo, ha de co...
#                                ...
# 16329    K&S es una productora argentina de cine, funda...
# 16330    Actividades del alfabeto - Letra K Educación i...
# 16331    Download K-Lite Codec Pack. There are four dif...
# 16332    My saves. My interests / My collections + New....
# 16333    Play next; Play now; Foam Clay Smiley Face Sur...
# Name: snippet, Length: 5223, dtype: object

# %%
# Descripción del desafio

summary = "Los estudiantes deben identificar diseños para crear un automóvil"

description = "Después de que la temporada de NASCAR abrió este año, su sobrina se interesó mucho en las carreras de derby de soapbox. Ya que sus padres están muy ocupados, ha acordado ayudarla a construir un automóvil para que pueda participar en una carrera local. El primer paso es averiguar cómo construir un automóvil . Identifique algunos diseños básicos que podría usar y cree un plan básico para construir el automóvil"

aim = "Identificar características necesarias para un automóvil en la participación de la carrera."

query = "Como construir un automovil"

# %% [markdown]
# ### Formulación y preprocesamiento del corpus
#
# Similar a lo realizado en 01_medicion_de_diversidad. Se genera un string auxiliar para lidiar con el manejo de tildes que permite unidecode.

# %%
import pandas as pd

corpus = df[:48].str.cat() # concatenee 48 snippets de la primera query del usuario

#https://rare-technologies.com/word2vec-tutorial/
#gensim’s word2vec expects a sequence of sentences
#sentences = [['first', 'sentence'], ['second', 'sentence']]

# %% [markdown]
# Fuente:
#
# https://stackabuse.com/implementing-word2vec-with-gensim-library-in-python/

# %%
#https://pynative.com/python-generate-random-string/

import string
from random import choice

letters = string.ascii_lowercase
aux_str = ''.join(choice(letters) for i in range(10))
aux_str # se debe verificar que sea una palabra unica al menos en teoria
# Out:
# 'eseugwnost'

# %%
from preprocessing import preprocessing # funcion propia

# %%
preprocessed_corpus = preprocessing(aux_str, corpus) # no tildes, ni signos ni espacios adicionales, e incluye 'ñ'

# %%
import nltk

# Preparación del dataset
all_sentences = nltk.sent_tokenize(preprocessed_corpus)

all_words = [nltk.word_tokenize(sent) for sent in all_sentences] #lista dentro de una lista

# %%
len(all_words[0])
# Out:
# 2382

# %%
from nltk.corpus import stopwords

es_sw = stopwords.words('spanish') # lista stopword a usar

# %%
# Eliminando stop words
for i in range(len(all_words)):
    all_words[i] = [w for w in all_words[i] if w not in es_sw]

# %%
len(all_words[0])
# Out:
# 1292

# %% [markdown]
# ### Creación del modelo
# Utilizando Gensim basado en Skip Gram

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(all_words, min_count=4, sg=1, window=5)

# %%
for i, word in enumerate(model.wv.vocab):
    if i == 9:
        break
    print(word)
# Out:
# construir
# auto
# años
# ago
# si
# alguna
# motor
# automovil
# tener

# %%
model.wv['auto']
# Out:
# array([-1.1469658e-03, -1.2876722e-04,  4.3897452e-03,  7.8630535e-04,
#         7.2832307e-04,  2.4555330e-03, -2.2590489e-03, -4.9282773e-04,
#         1.2653416e-03,  1.0591280e-03,  4.5172460e-03, -2.4821197e-03,
#        -1.8764600e-03,  6.0141361e-03,  2.0347929e-03, -2.8993008e-03,
#         4.2150072e-03, -2.4108901e-03,  1.1961388e-03,  1.1412635e-03,
#        -9.4593724e-04, -2.1498671e-03,  4.6116277e-03, -3.0033172e-03,
#        -3.1350304e-03, -1.8964104e-03, -1.6130136e-03, -3.7072620e-03,
#         2.9788290e-03,  1.5101940e-03, -2.5390550e-03,  1.1565788e-03,
#         3.8205558e-03, -4.1803783e-03, -2.1779661e-03, -1.6404985e-03,
#        -1.0742121e-03, -3.6182392e-03,  2.5134701e-03,  9.7049912e-04,
#        -6.6800689e-04,  2.9920295e-03, -2.7959347e-03, -2.9933548e-03,
#         3.4082499e-03,  2.2214367e-03,  2.2054724e-03, -5.0166943e-03,
#         6.2118284e-04,  2.7843975e-03,  3.5358206e-03,  1.6858638e-03,
#        -5.9998623e-04,  3.1258832e-03,  9.9449384e-04,  2.3520279e-03,
#        -4.3155118e-03, -2.0288131e-03,  4.2695259e-03,  2.9533778e-03,
#        -2.9403083e-03,  1.7377425e-03, -1.0191979e-03, -2.8807382e-05,
#        -5.2146004e-03, -3.7439028e-03, -2.8570448e-03,  2.9105828e-03,
#        -5.4258290e-03, -4.2809560e-03,  5.6080660e-04,  2.1469304e-03,
#         6.5038179e-04, -3.9033552e-03, -1.5496353e-03,  7.6721917e-04,
#         1.0826458e-03, -4.8028668e-03,  3.0235071e-03,  2.8497395e-03,
#         4.5115780e-03, -8.7272638e-04,  6.3658896e-04,  4.2999708e-03,
#         6.3253532e-04,  1.0660145e-04, -3.0824773e-03,  3.6889382e-03,
#         5.6978120e-03,  4.4563963e-04,  2.4912024e-03,  2.2305052e-03,
#         2.3768127e-03,  2.1210993e-03,  4.0156730e-03, -4.3725674e-03,
#        -5.3166733e-03,  3.8969524e-03,  3.6047990e-03,  1.6915966e-03],
#       dtype=float32)

# %%
try:
    display(model.wv.most_similar('auto', topn=30))
except KeyError:
    print("Esta palabra no aparece en el modelo")
# Out:
# [('motor', 0.2924947142601013),
#  ('llamo', 0.286482036113739),
#  ('alguna', 0.2758750915527344),
#  ('coche', 0.2497164011001587),
#  ('construye', 0.2457093596458435),
#  ('construir', 0.22628232836723328),
#  ('calles', 0.21788957715034485),
#  ('cuatro', 0.2169862985610962),
#  ('mecanica', 0.20561717450618744),
#  ('delantera', 0.2025432139635086),
#  ('puede', 0.19304320216178894),
#  ('forma', 0.1905452013015747),
#  ('belleza', 0.1858481466770172),
#  ('estilo', 0.1745622456073761),
#  ('remolcar', 0.16841167211532593),
#  ('automovil', 0.1680086851119995),
#  ('medio', 0.16589948534965515),
#  ('electrico', 0.1650107204914093),
#  ('inventor', 0.1599186807870865),
#  ('carrito', 0.15563732385635376),
#  ('aire', 0.15492123365402222),
#  ('mas', 0.15321822464466095),
#  ('paris', 0.14843732118606567),
#  ('vehiculo', 0.14723004400730133),
#  ('transporte', 0.1440119594335556),
#  ('cilindros', 0.13255473971366882),
#  ('estan', 0.12774570286273956),
#  ('tipo', 0.11815573275089264),
#  ('vez', 0.11453481018543243),
#  ('triciclo', 0.10808493196964264)]

# %% [markdown]
# Fuente:
#
# https://relopezbriega.github.io/blog/2017/09/23/procesamiento-del-lenguaje-natural-con-python/

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
# por último podemos graficar el modelo
vocab = list(model.wv.vocab)
X = model[vocab]

# aplicamos TSNE
tsne = TSNE(n_components=2) #herramienta para visualizar data de alta dimensionalidad
X_tsne = tsne.fit_transform(X)

# transformamos en DataFrame
df = pd.concat([pd.DataFrame(X_tsne),
                pd.Series(vocab)],
               axis=1)

df.columns = ['x', 'y', 'palabra']
# Out:
# /home/marriagada/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(vocab)
# Out:
# 57

# %%
# creamos el gráfico
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1)

# reducimos el dataset a 15 palabras para el ejemplo
df_e = df.head(len(vocab))

ax.scatter(df_e['x'], df_e['y'])

for i, txt in enumerate(df_e['palabra']):
    ax.annotate(txt, (df_e['x'].iloc[i], df_e['y'].iloc[i]))
    
plt.show()

# %% [markdown]
# https://radimrehurek.com/gensim/auto_examples/tutorials/run_word2vec.html#sphx-glr-auto-examples-tutorials-run-word2vec-py
