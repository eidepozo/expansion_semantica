# %% [markdown]
# @eidepozo

# %%
import pandas as pd

# %%
df = pd.read_csv('top_k_queries_ext.csv')

# %%
df
# Out:
#     total                                          query  \
# 0      24                    como construir un automovil
# 1      18                             como hacer un auto
# 2      10                               soapbox vehiculo
# 3       9        como construir un automovil de carreras
# 4       9                                   soapbox race
# 5       8                      automovil soapbox carrera
# 6       8                              construir un auto
# 7       8                 planes para crear un automovil
# 8       8                        construir un automóvil
# 9       7                                        soapbox
# 10      5  proceso de construcion de un auto para nascar
# 11      5                         partes de un automovil
#
#                                              snippet1  \
# 0   Los ocho pasos -y los cuatro años- para engend...
# 1   Es, según los responsables del diseño, intenci...
# 2   Hace algunos días te platicábamos sobre el nue...
# 3   Vemos todo el proceso que lleva modificar un S...
# 4   With Soapbox Race World, servers can provide c...
# 5   Este coche fue creado a partir de las carreras...
# 6   Desde que el diseñador dibuja hasta que los in...
# 7   Los ocho pasos -y los cuatro años- para engend...
# 8   Aunque la tecnología sea determinante, aún se ...
# 9   Soapbox is the only tool you need to record, e...
# 10  NASCAR es la categoría automovilística más com...
# 11  El chasis es el esqueleto de un auto. Puede se...
#
#                                              snippet2  \
# 0   AUTOS, VEHÍCULOS, TOPS, LOS MEJORES TOPS, IMPR...
# 1   En la planta de prensas, se han creado todas l...
# 2   Como cualquier vehículo, el Hyundai Soapbox fu...
# 3   Diseña el volante. Los corredores que agregan ...
# 4   Red Bull Soapbox Race 2019 went to Lithuania a...
# 5   A una carrera de Soapbox asisten cerca de 40,0...
# 6   AUTOS, VEHÍCULOS, TOPS, LOS MEJORES TOPS, IMPR...
# 7   Con una amplia experiencia en ingeniería, Delo...
# 8   Pues, en este reportaje, resolvemos tus dudas ...
# 9   Get Started - Soapbox - A Free Webcam and Scre...
# 10  Los ocho pasos -y los cuatro años- para engend...
# 11  Pedales o mandos de pie. El Acelerador: se acc...
#
#                                              snippet3   sum_cos
# 0   La fabricación de un coche se divide, fundamen...  0.135002
# 1   Hola amigos…. cómo hacer un auto fórmula 1, pa...  0.091870
# 2   El SoapBox es sencillo, la fuerza de gravedad ...  0.254699
# 3   utilizado como rueda, un hilo estriado como ej...  0.041160
# 4   soapbox race world is an open source project w...  0.487506
# 5   La carrera ‘Red Bull Soapbox Race’ se realiza ...  0.116018
# 6   Relájate y disfruta en HD del proceso de ensam...  0.030472
# 7   Uno de los proyectos que se espera de Apple es...  0.089464
# 8   Relájate y disfruta en HD del proceso de ensam...  0.038725
# 9   Soapbox Usage Guidelines. Ditto to what we sai...  0.426056
# 10  NASCAR son las iniciales en inglés de National...  0.227593
# 11  Partes de un coche Motor Neumáticos Chasis Car...  0.166078

# %%
modelA_q = [] # iterable df para cada query
modelB_q = []
modelC_q = []

# %%
file_names =['01', '02', '03', '05', '06', '07', '08']

# %%
for name in file_names:
    modelA_q.append(pd.read_csv('modelA/top_k_query_'+name+'.csv'))
    modelB_q.append(pd.read_csv('modelB/top_k_query_'+name+'.csv'))
    modelC_q.append(pd.read_csv('modelC/top_k_query_'+name+'.csv'))

# %%
modelA_q[0]
# Out:
#        word_added                                                 s1  \
# 0           puede  Es, según los responsables del diseño, intenci...
# 1          puedes  Los ocho pasos -y los cuatro años- para engend...
# 2          básico  Los 8 pasos esenciales para crear un auto 13 d...
# 3             dos  COMO HACER UN AUTO I y dos Misiles de Largo Al...
# 4          tiempo  Desde que Henry Ford instaurase en sus fábrica...
# 5           pasos  PASO 1 – Briefing Las líneas maestras que suje...
# 6          ruedas  Esta video muestra un prototipo de vehiculo ti...
# 7            debe  Donaciones para arreglarme el diente 😃😁😅: http...
# 8          pueden  Buenas amigos y amigas de youtube, en este víd...
# 9           forma  Alto y ancho En las áreas de alto y ancho, pue...
# 10            así  Así se hace: Un auto - YouTube. Así se hace: U...
# 11      cualquier  QUE ES COMO HACER UN AUTORUN o AUTOEJECUTABLE ...
# 12         casero  Como Hacer un Auto a Motor Eléctrico Casero (D...
# 13         manera  Los ocho pasos -y los cuatro años- para engend...
# 14          parte  Los 8 pasos esenciales para crear un auto 13 d...
# 15           tipo  Cómo dibujar un Auto de forma fácil para niños...
# 16       realizar  Los ocho pasos -y los cuatro años- para engend...
# 17     materiales  En éste vídeo haremos un bólido f1 usando para...
# 18        proceso  Los ocho pasos -y los cuatro años- para engend...
# 19       proyecto  Los ocho pasos -y los cuatro años- para engend...
# 20         chasis  El chasis de un carro / Parte 1 - YouTube. Des...
# 21        trabajo  PASO 1 – Briefing Las líneas maestras que suje...
# 22           cada  Los ocho pasos -y los cuatro años- para engend...
# 23           aire  Hola amigos en este vídeo vamos a hacer un car...
# 24   construcción  mexicanos participar en la construcción de sus...
# 25          mejor  TOP 10 PARA MEJORAR ESTETICAMENTE TU AUTO DARL...
# 26        motores  Como Hacer un Carro Eléctrico Casero de la pop...
# 27      eléctrico  En este primer vídeo les comentamos los primer...
# 28       vehículo  Los ocho pasos -y los cuatro años- para engend...
# 29      elementos  PASO 4 – Modelo de clay En esta fase del progr...
# 30    principales  Los ocho pasos -y los cuatro años- para engend...
# 31          niños  Subscríbanse por favor, activen la campana par...
# 32          crear  Los ocho pasos -y los cuatro años- para engend...
# 33       aprender  Paso a paso para aprender a manejar un auto Co...
# 34          mismo  Cómo conducir un auto manual y hacer los cambi...
# 35         propio  Los ocho pasos -y los cuatro años- para engend...
# 36           casa  Es, según los responsables del diseño, intenci...
# 37          motor  Como Hacer un Auto a Motor Eléctrico CaseroMAT...
# 38  mantenimiento  Al no ser un desgaste muy perceptible para el ...
# 39       gasolina  Cómo preparar un coche teledirigido de gasolin...
# 40        energía  Para proporcionar energía potencial a un siste...
# 41         cuenta  Cómo hacer el autologin o autorregistro en PASEN.
# 42          todas  Los ocho pasos -y los cuatro años- para engend...
# 43      necesario  Los ocho pasos -y los cuatro años- para engend...
# 44      automovil  Pues, en este reportaje, resolvemos tus dudas ...
# 45            bar  Con mis planos, puedes construir el tuyo de ma...
# 46         partes  Identifica los posibles proveedores. Deberás a...
# 47          vamos  Los ocho pasos -y los cuatro años- para engend...
# 48         diseño  Bienvenidos todos, hoy les traigo lo siguiente...
# 49       material  Cómo hacer un coche con botellas de plástico |...
#
#                                                    s2  \
# 0   Buenas amigos y amigas de youtube, en este víd...
# 1   Buenas amigos y amigas de youtube, en este víd...
# 2   Tutorial de modelado para principiantes con Bl...
# 3   Suele pesar el doble a un coche convencional. ...
# 4   Suscribirse a GENIAL: https://goo.gl/EP7ZgRIDE...
# 5   AUTOS, VEHÍCULOS, TOPS, LOS MEJORES TOPS, IMPR...
# 6   Método para ajustar la alineación de ruedas co...
# 7   Las entradas de auto o estacionamiento en una ...
# 8   Buenas amigos y amigas de youtube, en este víd...
# 9   Coloca una Autoforma 1 Busca el menú de Autofo...
# 10  Sin embargo, se podría decir que la confección...
# 11  En este vídeo les muestro como manejar o traba...
# 12  Buenas amigos y amigas de youtube, en este víd...
# 13  Como hacer un auto de carreras con diseño de f...
# 14  Dibuja un rectángulo delgado con la longitud q...
# 15  Es, según los responsables del diseño, intenci...
# 16  Desde aquellas primeras fábricas de coches has...
# 17  Manijas, tapetes, interruptores, ventilas del ...
# 18  Ayudados por robots, unos operarios están muy ...
# 19  Así que en primer lugar nos hacen falta ganas,...
# 20  Utiliza una sierra para metal para cortar mont...
# 21  Ideas de trabajo con auto propio Transporte es...
# 22  Modificar un auto puede ser muy costoso, sin e...
# 23  Como hacer un Aire Acondicionado Casero para t...
# 24  Haremos un marco de tabla de madera de 15 cm q...
# 25  Además del mantenimiento regular, debemos comp...
# 26  Hola amigos…. cómo hacer un auto fórmula 1, pa...
# 27  Como Hacer un Auto a Motor Eléctrico Casero ( ...
# 28  Como hacer un vehículo volador en Minecraft 🎮 ...
# 29  Paso a paso debes: Lija la zona donde vayas a ...
# 30  Extraiga lo esencial de su texto, resuma « de ...
# 31  www.Hobby-En-Como-Hacer.BlogSpot.com - ¿sabes ...
# 32  AUTOS, VEHÍCULOS, TOPS, LOS MEJORES TOPS, IMPR...
# 33  Aprender a manejar un auto es una labor que en...
# 34  A 6 cm desde el borde de la trasera pegar, con...
# 35  AUTOS, VEHÍCULOS, TOPS, LOS MEJORES TOPS, IMPR...
# 36  Las entradas de auto o estacionamiento en una ...
# 37  Hola amigos…. cómo hacer un auto fórmula 1, pa...
# 38  Es, con mucho, el mantenimiento preventivo más...
# 39  Visita nuestro sitio Web: http://bit.ly/2nT2Wz...
# 40  Un auto solar "casi" completamente hecho de ma...
# 41  Usaremos esta dirección para mantener tu cuent...
# 42  Preparación: (puedes buscarla en la imagen de ...
# 43  La fabricación de automóviles se refiere a la ...
# 44  Manualidades para muñecas: Cómo hacer un autom...
# 45  Debemos tener en cuenta varias cosas en este p...
# 46  PARA LOS VEHÍCULOS DE DISCAPACITADOS, EL GRABA...
# 47  Relájate y disfruta en HD del proceso de ensam...
# 48  Programas para diseñar coches. En la actualida...
# 49  Como hacer un auto de carreras con diseño de f...
#
#                                                    s3  similarity_w   sum_cos
# 0   Aprende paso a paso cómo hacer puente a un aut...      0.998811  0.150901
# 1   Modificar un auto puede ser muy costoso, sin e...      0.998742  0.027722
# 2   El proceso de diseño de un coche explicado en ...      0.998733  0.165487
# 3   En un ordenador, inicia sesión en la cuenta de...      0.998695  0.000000
# 4   Saca la Revisión Técnica: Uno de los requisito...      0.998533  0.000000
# 5   La fabricación de un coche se divide, fundamen...      0.998436  0.033745
# 6   DECORACIÓN CON RUEDAS DE AUTO🚗 COMO HACER MACE...      0.998431  0.109910
# 7   Estas son algunas de las preguntas más importa...      0.998344  0.047364
# 8   Considera encontrar un agente literario. Si qu...      0.998306  0.646223
# 9   Para escribir texto dentro de una autoforma se...      0.998296  0.253617
# 10  En este video les enseño como hacer un autp fu...      0.998256  0.036831
# 11  Hacker crea kit que puede hacer que cualquier ...      0.998250  0.102452
# 12  Como Hacer un Coche o Carro Casero de Madera C...      0.998245  0.365733
# 13  En este reportaje, vamos a ver cómo se fabrica...      0.998207  0.118241
# 14  Shopping. Tap to unmute. If playback doesn't b...      0.998147  0.018340
# 15  Solución: Cree manualmente un archivo de tipo ...      0.998127  0.086522
# 16  Auto-realizarse como persona. Seguramente todo...      0.998121  0.076746
# 17  Cinco kilos de arcilla y el trabajo de actuali...      0.997909  0.023263
# 18  Relájate y disfruta en HD del proceso de ensam...      0.997895  0.080635
# 19  descarga beat en tu iphone o android: http://o...      0.997890  0.029794
# 20  Para sujetar los motores al chasis vamos a nec...      0.997878  0.169280
# 21  Debe contar con vehículo propio (para venir a ...      0.997829  0.068483
# 22  About Press Copyright Contact us Creators Adve...      0.997808  0.037710
# 23  Las líneas continuas, las superficies fluidas,...      0.997782  0.155532
# 24  Este manual de construcción permitirá al autoc...      0.997753  0.146263
# 25  Cómo hacer que tu Auto sea más Rápido SIN MODI...      0.997749  0.150379
# 26  Step 1, Limpia minuciosamente el motor antes d...      0.997611  0.151534
# 27  Con el proyecto OSVehicle, no solo podemos con...      0.997551  0.168675
# 28  En total, debes sumar los siguientes montos: 2...      0.997536  0.033683
# 29  Generalmente se utilizan elementos como resort...      0.997530  0.131739
# 30  A la hora de fabricar un vehículo normalmente ...      0.997446  0.035797
# 31  como hacer un automovil electrico para niños E...      0.997200  0.092194
# 32  Relájate y disfruta en HD del proceso de ensam...      0.997079  0.064121
# 33  Hola a todos, este canal está dedicado a enseñ...      0.997079  0.183599
# 34  Paso 1: familiarizarse con el pedal de embragu...      0.997070  0.100362
# 35  - Primero se hace un enchapado con aluminio y ...      0.997067  0.037873
# 36  2. Planifica el tamaño, la forma y la ruta de ...      0.997004  0.029115
# 37  - Hola como están este video aprenderemos A CO...      0.996885  0.211405
# 38  Una parte fundamental en el mantenimiento de u...      0.996821  0.109118
# 39  Convierte tu auto de GASOLINA a ELÉCTRICO - Yo...      0.996781  0.042573
# 40  Cómo hacer un auto de juguete impulsado por en...      0.996650  0.170309
# 41  Utilizaremos esta dirección, entre otras cosas...      0.996590  0.434579
# 42  VEHICULOS TODO TERRENO - BUGGY TRES RUEDAS - C...      0.996547  0.000000
# 43  Cómo hacer un auto simple - muy fáciltrack:Ele...      0.996518  0.027053
# 44  Los ocho pasos -y los cuatro años- para engend...      0.996491  0.126564
# 45  Como se dice, en gustos se rompen géneros, y n...      0.996436  0.014351
# 46  Así, hay algunas que son perfectas para áreas ...      0.996399  0.000000
# 47  Aprende como hacer un auto de carton de manera...      0.996369  0.131896
# 48  Un ejemplo de ello es el diseño interior o ext...      0.996360  0.038216
# 49  Cinco kilos de arcilla y el trabajo de actuali...      0.996334  0.045792

# %%
word_added = [] # iterable para evaluar vocabularios post modelo

# %%
for ele in range(len(file_names)):
    aux = pd.concat([modelA_q[ele]['word_added'],
                                 modelB_q[ele]['word_added'], modelC_q[ele]['word_added']], axis=1)
    aux.columns=['model_A', 'model_B', 'model_C']
    word_added.append(aux)

# %%
ref = {
    0: 1,
    1: 2,
    2: 3,
    3: 5,
    4: 6,
    5: 7,
    6: 8,
}

# %%
df.iloc[ref[4]]#[5]
# Out:
# total                                                       8
# query                                       construir un auto
# snippet1    Desde que el diseñador dibuja hasta que los in...
# snippet2    AUTOS, VEHÍCULOS, TOPS, LOS MEJORES TOPS, IMPR...
# snippet3    Relájate y disfruta en HD del proceso de ensam...
# sum_cos                                             0.0304718
# Name: 6, dtype: object

# %%
modelB_q[4][modelB_q[4]['sum_cos']<=df.iloc[ref[4]][5]].sort_values(by=['sum_cos'])[['word_added','sum_cos']][:15]
# Out:
#      word_added   sum_cos
# 1          debe  0.000000
# 32       básico  0.000000
# 25  principales  0.000000
# 40        crear  0.000000
# 13     aprender  0.000000
# 22      proceso  0.000000
# 7      realizar  0.000000
# 5        tiempo  0.000000
# 12       chasis  0.000000
# 42        plano  0.000000
# 8        pueden  0.019827
# 21    elementos  0.019996
# 33       dentro  0.023702
# 31   necesarios  0.026466
# 36      posible  0.026958

# %%
sum_cos1 = pd.concat([modelB_q[0][0:10]['sum_cos'],modelB_q[1][0:10]['sum_cos'],modelB_q[2][0:10]['sum_cos'],
                      modelB_q[3][0:10]['sum_cos'],modelB_q[4][0:10]['sum_cos'],modelB_q[5][0:10]['sum_cos'],
                      modelB_q[6][0:10]['sum_cos']])

# %%
sum_cos2 = pd.concat([modelB_q[0][10:20]['sum_cos'],modelB_q[1][10:20]['sum_cos'],modelB_q[2][10:20]['sum_cos'],
                      modelB_q[3][10:20]['sum_cos'],modelB_q[4][10:20]['sum_cos'],modelB_q[5][10:20]['sum_cos'],
                      modelB_q[6][10:20]['sum_cos']])

# %%
sum_cos3 = pd.concat([modelB_q[0][20:30]['sum_cos'],modelB_q[1][20:30]['sum_cos'],modelB_q[2][20:30]['sum_cos'],
                      modelB_q[3][20:30]['sum_cos'],modelB_q[4][20:30]['sum_cos'],modelB_q[5][20:30]['sum_cos'],
                      modelB_q[6][20:30]['sum_cos']])

# %%
sum_cos4 = pd.concat([modelB_q[0][30:40]['sum_cos'],modelB_q[1][30:40]['sum_cos'],modelB_q[2][30:40]['sum_cos'],
                      modelB_q[3][30:40]['sum_cos'],modelB_q[4][30:40]['sum_cos'],modelB_q[5][30:40]['sum_cos'],
                      modelB_q[6][30:40]['sum_cos']])

# %%
sum_cos5 = pd.concat([modelB_q[0][40:50]['sum_cos'],modelB_q[1][40:50]['sum_cos'],modelB_q[2][40:50]['sum_cos'],
                      modelB_q[3][40:50]['sum_cos'],modelB_q[4][40:50]['sum_cos'],modelB_q[5][40:50]['sum_cos'],
                      modelB_q[6][40:50]['sum_cos']])

# %%
sum_cos5.describe()
# Out:
# count    70.000000
# mean      0.141023
# std       0.168645
# min       0.000000
# 25%       0.038812
# 50%       0.101544
# 75%       0.159853
# max       0.969643
# Name: sum_cos, dtype: float64

# %%
sum_cos_mean_g2 =[0.160817,0.183363,0.128099,0.106497,0.141023]

# %%
import numpy as np

# %%
np.mean(sum_cos_mean_g2)
# Out:
# 0.1439598

# %%
#https://stackoverflow.com/questions/26977076/pandas-unique-values-multiple-columns

def uniqueness(word_added, idx):
    unique = list(pd.unique(word_added[idx][['model_A', 'model_B', 'model_C']].values.ravel('K')))
    unique_df = pd.DataFrame(unique, columns=['word'])
    unique_df['model_A'] = unique_df['word'].isin(word_added[idx]['model_A'])
    unique_df['model_B'] = unique_df['word'].isin(word_added[0]['model_B'])
    unique_df['model_C'] = unique_df['word'].isin(word_added[0]['model_C'])
    return unique_df

# %%
uniqueness(word_added, 6)
# Out:
#            word  model_A  model_B  model_C
# 0      vehículo     True    False    False
# 1   componentes     True    False    False
# 2        partes     True    False    False
# 3        diseño     True    False    False
# 4         parte     True     True     True
# ..          ...      ...      ...      ...
# 67     potencia    False    False    False
# 68      utiliza    False    False    False
# 69  transmisión    False    False    False
# 70  combustible    False    False    False
# 71       cuatro    False    False    False
#
# [72 rows x 4 columns]

# %%
def query_scatter_plot(index, user_id, df): # al tratar con df debe indicarse el usuario puntual
    plot_0 = modelA_q[index].plot.scatter(x='similarity_w', y='sum_cos', title=df.iloc[user_id][1], figsize=(10,5), label='Modelo A')
    modelB_q[index].plot.scatter(x='similarity_w', y='sum_cos', ax=plot_0, color='green', label="Modelo B")
    modelC_q[index].plot.scatter(x='similarity_w', y='sum_cos', ax=plot_0, color='orange', label="Modelo C")
    plot_0.axhline(y=df.iloc[user_id][5], color ='r', label= "{:.6f}".format(df.iloc[user_id][5]))
    plot_0.legend(loc=1)

# %%
keylist = list(ref)

# %%
query_scatter_plot(keylist[4],ref[4], df) # A : B

# %%
similarity_df = pd.DataFrame()

# %%
for i in range(len(file_names)):
    aux_list = [modelA_q[i]['similarity_w'].mean(), modelA_q[i]['similarity_w'].std(), modelB_q[i]['similarity_w'].mean(),
            modelB_q[i]['similarity_w'].std(), modelC_q[i]['similarity_w'].mean(), modelC_q[i]['similarity_w'].std()]
    aux_df = pd.DataFrame([aux_list])
    similarity_df = pd.concat([similarity_df, aux_df])

# %%
similarity_df = similarity_df.rename(columns={0: "modelA_mean", 1: "modelA_std", 2: "modelB_mean", 3: 'modelB_std', 4: 'modelC_mean', 5: 'modelC_std'}).reset_index(drop=True)

# %%
similarity_df
# Out:
#    modelA_mean  modelA_std  modelB_mean  modelB_std  modelC_mean  modelC_std
# 0     0.997571    0.000761     0.997872    0.000490     0.998737    0.000141
# 1     0.999514    0.000027     0.999449    0.000036     0.999402    0.000035
# 2     0.993327    0.001462     0.995837    0.000636     0.998130    0.000225
# 3     0.933378    0.016796     0.948378    0.012664     0.980687    0.004077
# 4     0.997571    0.000761     0.997872    0.000490     0.998737    0.000141
# 5     0.998434    0.000213     0.997925    0.000277     0.998853    0.000092
# 6     0.995352    0.001296     0.994521    0.001604     0.997770    0.000323

# %%
similarity_df.describe()
# Out:
#        modelA_mean  modelA_std  modelB_mean  modelB_std  modelC_mean  \
# count     7.000000    7.000000     7.000000    7.000000     7.000000
# mean      0.987878    0.003045     0.990265    0.002314     0.996045
# std       0.024120    0.006086     0.018540    0.004590     0.006793
# min       0.933378    0.000027     0.948378    0.000036     0.980687
# 25%       0.994339    0.000487     0.995179    0.000384     0.997950
# 50%       0.997571    0.000761     0.997872    0.000490     0.998737
# 75%       0.998002    0.001379     0.997898    0.001120     0.998795
# max       0.999514    0.016796     0.999449    0.012664     0.999402
#
#        modelC_std
# count    7.000000
# mean     0.000719
# std      0.001484
# min      0.000035
# 25%      0.000116
# 50%      0.000141
# 75%      0.000274
# max      0.004077

# %%
A = similarity_df['modelA_mean'].mean()
B = similarity_df['modelB_mean'].mean()
C = similarity_df['modelC_mean'].mean()
np.mean([A,B,C]), np.std([A,B,C])
# Out:
# (0.9913959571861085, 0.0034288807618961105)

# %%
under_margin = pd.DataFrame()

# %%
for i in range(len(file_names)):
    a = len(modelA_q[i][modelA_q[i]['sum_cos']<= df.iloc[ref[i]][5]].index)/len(modelA_q[i].index)#*100
    b = len(modelB_q[i][modelB_q[i]['sum_cos']<= df.iloc[ref[i]][5]].index)/len(modelB_q[i].index)#*100
    c = len(modelC_q[i][modelC_q[i]['sum_cos']<= df.iloc[ref[i]][5]].index)/len(modelC_q[i].index)#*100
    l = [df.iloc[ref[i]][5], a,b,c]
    auxdf = pd.DataFrame([l])
    under_margin = pd.concat([under_margin, auxdf])

# %%
under_margin = under_margin.rename(columns={0: "sum_cos_ori", 1: "modelA", 2: "modelB", 3: 'modelC'}).reset_index(drop=True)

# %%
under_margin
# Out:
#    sum_cos_ori  modelA  modelB  modelC
# 0     0.091870    0.52    0.60    0.58
# 1     0.254699    0.50    0.54    0.50
# 2     0.041160    0.62    0.62    0.56
# 3     0.116018    0.22    0.24    0.26
# 4     0.030472    0.32    0.34    0.32
# 5     0.089464    0.74    0.76    0.62
# 6     0.038725    0.28    0.22    0.22

# %%
under_margin['modelB'][6]
# Out:
# 0.22

# %% [markdown]
# 2 terminos
# G2
#
# 2 soapbox vehiculo: 0.54
#
# 3 terminos
# G2
#
# 4 automovil soapbox carrera: 0.24
#
# 5 construir un auto: 0.34
#
# 7 construir un automovil : 0.22
#
# 4 terminos
# G2
#
# 1 Como hacer un auto : 0.6
#
# 5 terminos
# G2
#
# 6 planes para crear un automovil: 0.76
#
#
# 6 terminos
# G2
#
# 3 como construir un automovil de carreras: 0.62

# %%
under_margin.describe()
# Out:
#        sum_cos_ori    modelA    modelB    modelC
# count     7.000000  7.000000  7.000000  7.000000
# mean      0.094630  0.457143  0.474286  0.437143
# std       0.077690  0.190938  0.208395  0.165903
# min       0.030472  0.220000  0.220000  0.220000
# 25%       0.039942  0.300000  0.290000  0.290000
# 50%       0.089464  0.500000  0.540000  0.500000
# 75%       0.103944  0.570000  0.610000  0.570000
# max       0.254699  0.740000  0.760000  0.620000

# %%
modelB_pair = pd.DataFrame()

# %%
for i in range(len(file_names)):
    case =  modelB_q[i][['similarity_w','sum_cos']]
    modelB_pair = pd.concat([modelB_pair, case])

# %%
modelB_pair = modelB_pair.reset_index(drop=True)

# %%
#modelB_pair.to_csv('g2_modelB_pairs.csv', index=False)
