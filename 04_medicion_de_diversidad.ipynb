# %% [markdown]
# @eidepozo
#
# ## Medición de diversidad
#
# Incluye la exportación del dataset con su valor de diversidad $sum\_cos$, definido como: *la suma de cada par único de snippets bajo similitud del coseno (sim)*
#
# \begin{equation}
# \label{eqn:sum_cos}
# sum\_cos(q) = \sum_{\substack{i \in I \\ i < j}} \sum_{j \in I} sim(s_{i}, s_{j}), \quad s_i, s_j \in S
# \end{equation}
#
# con $N$ snippets e $I = \{1,\ldots, N\}$

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.data_extraction import data_extraction
from src.filtering import filtering

# %%
data = data_extraction(4)

# %%
from bs4 import BeautifulSoup

# %%
data['snippet'] = data['snippet'].map(lambda text: BeautifulSoup(text, 'html.parser').get_text())

# %%
aux = data.groupby('id_number').head(3).groupby('FK_student_nick').head(3)
#aux # 3 primeros resultados para cada usuario de su primera query emitida

# %%
df = aux.drop_duplicates(['FK_student_nick','query'])[['FK_student_nick', 'query']] # primera query unica
df = df.reset_index(drop=True)

# %%
df['snippet1'] = aux['snippet'].iloc[::3].reset_index(drop=True) # 3 documentos por usuario
df['snippet2'] = aux['snippet'].iloc[1::3].reset_index(drop=True)
df['snippet3'] = aux['snippet'].iloc[2::3].reset_index(drop=True)

# %%
df
# Out:
#    FK_student_nick                                              query  \
# 0       aarriagada                        como construir un automovil
# 1          cduarte                                            soapbox
# 2         abastian                               Crear un auto básico
# 3       ocontreras                         Como construir un automovi
# 4         gcurguan                 Como construir un auto de carreras
# 5           mcarep                  construir automovil derby soapbox
# 6        eespinoza           como construir un automovil de carrerqas
# 7         gandrade   que debe tener mi auto para competir en nascar?
# 8       jfernandez                                                asd
# 9          bcortes                        componentes de un automovil
# 10    nguentalican                        como construir un automovil
# 11          dhofer                 plan basico para construir un auto
# 12       mescobarp                             partes de un automovil
# 13      chenriquez                            construir un automóvil
# 14         lguzman                        como construir un automovil
# 15          jgomez                            roblox como crear autos
# 16         mcatril                     como crear un auto para nazcar
# 17       fcastillo                    diseños basicos de un automovil
# 18      marriagada                        como construir un automovil
# 19        nhuaquil               pasos basicos para construir un auto
# 20         mgatica             Como construir un automovil de carrera
# 21        rfuentes                  pasos para construir un automovil
# 22        jbarriap               como hace un auto en chile en python
# 23       mgallardo             carateristicas necesarias para un auto
# 24        ahidalgo  diseños basicos para la construccion de un aut...
# 25     ehernandesp  como hacer un auto para carreras de derby de s...
# 26       jgonzalez                                   soapbox carreras
# 27         scortez                        como construir un automovil
# 28       falvarado                       arquitectura de un automovil
# 29          aduque                                      autos soapbox
#
#                                              snippet1  \
# 0   Cómo construir un auto deportivo con poco dine...
# 1   Soapbox is a Chrome extension that enables any...
# 2   This feature is not available right now. Pleas...
# 3   Construir un motor de automóvil desde cero, ll...
# 4   QUIERES FORMAR PARTE DE LA MEJOR NETWORK DE YO...
# 5   Fácil Soap Box Derby coche construir Estas ins...
# 6   Construye un automóvil de carreras casero y se...
# 7   Están preparados para competir más de 500 mill...
# 8   Anchorage School District website accessibilit...
# 9   El primer viaje largo en un automóvil lo reali...
# 10  Cómo construir un auto deportivo con poco dine...
# 11  Cómo construir un go kart. En este artículo: P...
# 12  Chasis Chasis de un automóvil. Constituye la e...
# 13  La fabricación de automóviles se refiere a la ...
# 14  Cómo construir un auto deportivo con poco dine...
# 15  Como CREAR TU PROPIO COCHE en ROBLOX muy FACIL...
# 16  La tecnología de innovación de los últimos año...
# 17  El término automóvil (del griego auto, "por sí...
# 18  Cómo construir un auto deportivo con poco dine...
# 19  Guía paso a paso para construir tu propio auto...
# 20  Construye un automóvil de carreras casero y se...
# 21  Los 8 pasos esenciales para crear un auto El p...
# 22  Stack Overflow en español es un sitio de pregu...
# 23  La siguiente figura resume rápidamente la func...
# 24  Durante años el chasis tal y como se ha explic...
# 25  Inspírate para Red Bull Soapbox Race con 10 au...
# 26  Una curiosa y bizarra carrera se desarrolla en...
# 27  Cómo construir un auto deportivo con poco dine...
# 28  La relación entre automóviles y arquitectura n...
# 29  Encuentra el Seguro Obligatorio Automotriz SOA...
#
#                                              snippet2  \
# 0   Construir un motor de automóvil desde cero, ll...
# 1   SoapBox is an app designed to help managers ha...
# 2   PARA HACER CAPAS MIRA EL Anexo a Curso de Auto...
# 3   Cómo construir un auto deportivo con poco dine...
# 4   Un auto de carrera puede ser un juego o un obj...
# 5   Sobre soap box derby de coches Soap box derby ...
# 6   Un auto de carrera puede ser un juego o un obj...
# 7   Hay una frase muy importante en estados Unidos...
# 8   Tip: Incorrect ASD file association errors can...
# 9   COMPONENTES DE UN AUTOMOVIL 1. PistónFoto de u...
# 10  Construir un motor de automóvil desde cero, ll...
# 11  El mejor programa gratuito para diseñar modelo...
# 12  Los frenos de un auto son una de las partes de...
# 13  Cómo construir un auto deportivo con poco dine...
# 14  Construir un motor de automóvil desde cero, ll...
# 15  This feature is not available right now. Pleas...
# 16  Hola amigos en este vídeo vamos a hacer un car...
# 17  Te mostramos cómo realizar el mantenimiento bá...
# 18  Construir un motor de automóvil desde cero, ll...
# 19  Unas enormes bovinas de acero, con un peso de ...
# 20  Un auto de carrera puede ser un juego o un obj...
# 21  Bueno, si eres del club de los de "poca pasta ...
# 22  Una pareja de triples comillas también permite...
# 23  Para aprovechar tanto las semiondas positivas ...
# 24  Para nuestro caso de estudio, el proyecto arqu...
# 25  Cómo hacer un carro de plataforma improvisada....
# 26  Red Bull Soap Box Car Race, Bergen 2013 Rolf R...
# 27  Construir un motor de automóvil desde cero, ll...
# 28  Así la Municipalidad de Miraflores pondría a r...
# 29  Need for Speed World Online en 3DJuegos: Bueno...
#
#                                              snippet3
# 0   Relájate y disfruta en HD del proceso de ensam...
# 1   A soapbox is a raised platform on which one st...
# 2   Crear un diagrama de flujo. En el menú Archivo...
# 3   Fases. Antes de producir un vehículo, ha de co...
# 4   UN COCHE DE CARRERAS DEFINICIÓN DEL PROYECTO. ...
# 5   3rd Annual Nevada City Soap Box Derby. 3rd Ann...
# 6   Estudiantes de la Universidad Politécnica Sale...
# 7   NASCAR hace referencia a las siglas en inglés ...
# 8   Definición de ASD en el Diccionario de español...
# 9   Curso Mecánica: Experto en Autopartes | Compon...
# 10  Relájate y disfruta en HD del proceso de ensam...
# 11  Si te dedicas a las ventas y te gustaría ser u...
# 12  Partes de un automóvil. El automóvil es un med...
# 13  Nicolas-Joseph Cugnot (1725-1804), , escritor ...
# 14  Relájate y disfruta en HD del proceso de ensam...
# 15  Como usar auto clicker para Roblox. Distintas ...
# 16  La tecnología de innovación de los últimos año...
# 17  Hoy voy a compartir con uds. la forma de model...
# 18  Relájate y disfruta en HD del proceso de ensam...
# 19  Cómo construir un carro de LEGO. Hay muchas ma...
# 20  Estudiantes de la Universidad Politécnica Sale...
# 21  Cómo se fabrica un coche, en cuatro pasos. Rep...
# 22  Mi padre es discapacitado 100% y esta en trami...
# 23  Poco antes del patinaje ya la batería a duras ...
# 24  Muy interesante la construcción y cuidado de u...
# 25  Los carros que hayan sido seleccionados para c...
# 26  Bueno, incluso bajo su perfil más complejo, el...
# 27  Relájate y disfruta en HD del proceso de ensam...
# 28  Sin duda el automóvil es una pieza clave en la...
# 29  El SOAP, o Seguro Obligatorio de Accidentes Pe...

# %%
#https://goodboychan.github.io/chans_jupyter/python/datacamp/natural_language_processing/2020/07/17/04-TF-IDF-and-similarity-scores.html#Cosine-similarity
#https://gist.github.com/4OH4/bea12f336b154e25ac33acbc76cd5f0a

from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
es_sw = stopwords.words('spanish')

# %%
tf = TfidfVectorizer(stop_words=es_sw)

# %%
from recomendacion_de_terminos.src.metrics import sim_matrix, group_matrix
import numpy as np

# %% [markdown]
# Ej. del proceso para query 20

# %%
q = df['query'][20]
s1 = df['snippet1'][20]
s2 = df['snippet2'][20]
s3 = df['snippet3'][20]

# %%
q
# Out:
# 'Como construir un automovil de carrera'

# %%
tfidf_matrix = tf.fit_transform([q,s1,s2,s3]) # matriz de caracteristicas

# %%
feature_names = tf.get_feature_names()
for x in feature_names:
    print(x, end=' ')
# Out:
# aerodinámica auto automotriz automovil automóvil carrera carreras casero colección computarizados construcción construir construye controles cuenca duda electrónicos enseñaremos estilo estudiantes forma fórmula grupo hacemos historia ingeniería juego juegos madera mantiene mayor miembro mismos objeto parte pasatiempo pertenecientes politécnica proyecto puede realizan salesiana sede selecto ser si universidad valor vehículo vida

# %%
print(tfidf_matrix[0])
# Out:
#   (0, 5)	0.4480997313625986
#   (0, 3)	0.7020348194149619
#   (0, 11)	0.5534923152870045

# %%
from sklearn.metrics.pairwise import linear_kernel

# %%
S = [] # estimacion de similitud del coseno
for i in range(4): # largo del corpus
    S.append(linear_kernel(tfidf_matrix[i], tfidf_matrix).flatten())

# %%
S = np.asarray((S[0],S[1],S[2],S[3]))

# %%
S
# Out:
# array([[1.        , 0.        , 0.21377703, 0.14469256],
#        [0.        , 1.        , 0.        , 0.        ],
#        [0.21377703, 0.        , 1.        , 0.08738573],
#        [0.14469256, 0.        , 0.08738573, 1.        ]])

# %%
tf = TfidfVectorizer(stop_words=es_sw)  # reset para aplicar la funcion a los participantes

# %%
S = group_matrix(df, tf)

# %%
S # matriz de similitud
.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00],
#         [ 1.00000000e+00,  3.33066907e-16,  1.00000000e+00,
#           9.77705722e-01],
#         [ 1.00000000e+00,  1.00000000e+00,  3.33066907e-16,
#           9.75034342e-01],
#         [ 1.00000000e+00,  9.77705722e-01,  9.75034342e-01,
#           5.55111512e-16]],
#
#        [[ 4.44089210e-16,  8.82167634e-01,  7.33359370e-01,
#           9.57561643e-01],
#         [ 8.82167634e-01,  7.77156117e-16,  9.40466118e-01,
#           1.00000000e+00],
#         [ 7.33359370e-01,  9.40466118e-01,  5.55111512e-16,
#           9.85705568e-01],
#         [ 9.57561643e-01,  1.00000000e+00,  9.85705568e-01,
#           8.88178420e-16]],
#
#        [[ 0.00000000e+00,  1.00000000e+00,  9.27455536e-01,
#           7.55918624e-01],
#         [ 1.00000000e+00,  3.33066907e-16,  1.00000000e+00,
#           1.00000000e+00],
#         [ 9.27455536e-01,  1.00000000e+00,  6.66133815e-16,
#           9.28262281e-01],
#         [ 7.55918624e-01,  1.00000000e+00,  9.28262281e-01,
#           2.22044605e-16]],
#
#        [[ 0.00000000e+00,  8.96145770e-01,  9.37722385e-01,
#           1.00000000e+00],
#         [ 8.96145770e-01,  4.44089210e-16,  9.77656827e-01,
#           9.32096698e-01],
#         [ 9.37722385e-01,  9.77656827e-01,  0.00000000e+00,
#           1.00000000e+00],
#         [ 1.00000000e+00,  9.32096698e-01,  1.00000000e+00,
#           4.44089210e-16]],
#
#        [[ 2.22044605e-16,  9.50470033e-01,  9.51976177e-01,
#           9.52556093e-01],
#         [ 9.50470033e-01,  0.00000000e+00,  9.88886690e-01,
#           9.38899187e-01],
#         [ 9.51976177e-01,  9.88886690e-01,  6.66133815e-16,
#           9.89354751e-01],
#         [ 9.52556093e-01,  9.38899187e-01,  9.89354751e-01,
#           4.44089210e-16]],
#
#        [[ 0.00000000e+00,  1.00000000e+00,  9.18214120e-01,
#           1.00000000e+00],
#         [ 1.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#           7.72827920e-01],
#         [ 9.18214120e-01,  1.00000000e+00,  4.44089210e-16,
#           1.00000000e+00],
#         [ 1.00000000e+00,  7.72827920e-01,  1.00000000e+00,
#           6.66133815e-16]]])

# %%
S[0] # 29 submatrices de similitud por usuario, query y 3 snippets respectivas
# Out:
# array([[0.00000000e+00, 8.96145770e-01, 9.37722385e-01, 1.00000000e+00],
#        [8.96145770e-01, 4.44089210e-16, 9.77656827e-01, 9.32096698e-01],
#        [9.37722385e-01, 9.77656827e-01, 0.00000000e+00, 1.00000000e+00],
#        [1.00000000e+00, 9.32096698e-01, 1.00000000e+00, 4.44089210e-16]])

# %%
df['sum_cos'] = "" # arreglo

# %%
# estimación del "puntaje del coseno" = suma de similaridad entre snippets por usuario
# a medida que disminuye mayor es la diversidad
for i in range(S.shape[0]):
    df['sum_cos'][i] = S[i][1,2] + S[i][1,3] + S[i][2,3]

# %%
df
# Out:
#    FK_student_nick                                              query  \
# 0       aarriagada                        como construir un automovil
# 1          cduarte                                            soapbox
# 2         abastian                               Crear un auto básico
# 3       ocontreras                         Como construir un automovi
# 4         gcurguan                 Como construir un auto de carreras
# 5           mcarep                  construir automovil derby soapbox
# 6        eespinoza           como construir un automovil de carrerqas
# 7         gandrade   que debe tener mi auto para competir en nascar?
# 8       jfernandez                                                asd
# 9          bcortes                        componentes de un automovil
# 10    nguentalican                        como construir un automovil
# 11          dhofer                 plan basico para construir un auto
# 12       mescobarp                             partes de un automovil
# 13      chenriquez                            construir un automóvil
# 14         lguzman                        como construir un automovil
# 15          jgomez                            roblox como crear autos
# 16         mcatril                     como crear un auto para nazcar
# 17       fcastillo                    diseños basicos de un automovil
# 18      marriagada                        como construir un automovil
# 19        nhuaquil               pasos basicos para construir un auto
# 20         mgatica             Como construir un automovil de carrera
# 21        rfuentes                  pasos para construir un automovil
# 22        jbarriap               como hace un auto en chile en python
# 23       mgallardo             carateristicas necesarias para un auto
# 24        ahidalgo  diseños basicos para la construccion de un aut...
# 25     ehernandesp  como hacer un auto para carreras de derby de s...
# 26       jgonzalez                                   soapbox carreras
# 27         scortez                        como construir un automovil
# 28       falvarado                       arquitectura de un automovil
# 29          aduque                                      autos soapbox
#
#                                              snippet1  \
# 0   Cómo construir un auto deportivo con poco dine...
# 1   Soapbox is a Chrome extension that enables any...
# 2   This feature is not available right now. Pleas...
# 3   Construir un motor de automóvil desde cero, ll...
# 4   QUIERES FORMAR PARTE DE LA MEJOR NETWORK DE YO...
# 5   Fácil Soap Box Derby coche construir Estas ins...
# 6   Construye un automóvil de carreras casero y se...
# 7   Están preparados para competir más de 500 mill...
# 8   Anchorage School District website accessibilit...
# 9   El primer viaje largo en un automóvil lo reali...
# 10  Cómo construir un auto deportivo con poco dine...
# 11  Cómo construir un go kart. En este artículo: P...
# 12  Chasis Chasis de un automóvil. Constituye la e...
# 13  La fabricación de automóviles se refiere a la ...
# 14  Cómo construir un auto deportivo con poco dine...
# 15  Como CREAR TU PROPIO COCHE en ROBLOX muy FACIL...
# 16  La tecnología de innovación de los últimos año...
# 17  El término automóvil (del griego auto, "por sí...
# 18  Cómo construir un auto deportivo con poco dine...
# 19  Guía paso a paso para construir tu propio auto...
# 20  Construye un automóvil de carreras casero y se...
# 21  Los 8 pasos esenciales para crear un auto El p...
# 22  Stack Overflow en español es un sitio de pregu...
# 23  La siguiente figura resume rápidamente la func...
# 24  Durante años el chasis tal y como se ha explic...
# 25  Inspírate para Red Bull Soapbox Race con 10 au...
# 26  Una curiosa y bizarra carrera se desarrolla en...
# 27  Cómo construir un auto deportivo con poco dine...
# 28  La relación entre automóviles y arquitectura n...
# 29  Encuentra el Seguro Obligatorio Automotriz SOA...
#
#                                              snippet2  \
# 0   Construir un motor de automóvil desde cero, ll...
# 1   SoapBox is an app designed to help managers ha...
# 2   PARA HACER CAPAS MIRA EL Anexo a Curso de Auto...
# 3   Cómo construir un auto deportivo con poco dine...
# 4   Un auto de carrera puede ser un juego o un obj...
# 5   Sobre soap box derby de coches Soap box derby ...
# 6   Un auto de carrera puede ser un juego o un obj...
# 7   Hay una frase muy importante en estados Unidos...
# 8   Tip: Incorrect ASD file association errors can...
# 9   COMPONENTES DE UN AUTOMOVIL 1. PistónFoto de u...
# 10  Construir un motor de automóvil desde cero, ll...
# 11  El mejor programa gratuito para diseñar modelo...
# 12  Los frenos de un auto son una de las partes de...
# 13  Cómo construir un auto deportivo con poco dine...
# 14  Construir un motor de automóvil desde cero, ll...
# 15  This feature is not available right now. Pleas...
# 16  Hola amigos en este vídeo vamos a hacer un car...
# 17  Te mostramos cómo realizar el mantenimiento bá...
# 18  Construir un motor de automóvil desde cero, ll...
# 19  Unas enormes bovinas de acero, con un peso de ...
# 20  Un auto de carrera puede ser un juego o un obj...
# 21  Bueno, si eres del club de los de "poca pasta ...
# 22  Una pareja de triples comillas también permite...
# 23  Para aprovechar tanto las semiondas positivas ...
# 24  Para nuestro caso de estudio, el proyecto arqu...
# 25  Cómo hacer un carro de plataforma improvisada....
# 26  Red Bull Soap Box Car Race, Bergen 2013 Rolf R...
# 27  Construir un motor de automóvil desde cero, ll...
# 28  Así la Municipalidad de Miraflores pondría a r...
# 29  Need for Speed World Online en 3DJuegos: Bueno...
#
#                                              snippet3  sum_cos
# 0   Relájate y disfruta en HD del proceso de ensam...  2.90975
# 1   A soapbox is a raised platform on which one st...  2.69978
# 2   Crear un diagrama de flujo. En el menú Archivo...  2.98881
# 3   Fases. Antes de producir un vehículo, ha de co...  2.92094
# 4   UN COCHE DE CARRERAS DEFINICIÓN DEL PROYECTO. ...  2.85595
# 5   3rd Annual Nevada City Soap Box Derby. 3rd Ann...  2.57605
# 6   Estudiantes de la Universidad Politécnica Sale...  2.86337
# 7   NASCAR hace referencia a las siglas en inglés ...   2.8047
# 8   Definición de ASD en el Diccionario de español...  2.91122
# 9   Curso Mecánica: Experto en Autopartes | Compon...  2.94154
# 10  Relájate y disfruta en HD del proceso de ensam...  2.90975
# 11  Si te dedicas a las ventas y te gustaría ser u...  2.95762
# 12  Partes de un automóvil. El automóvil es un med...  2.85765
# 13  Nicolas-Joseph Cugnot (1725-1804), , escritor ...  2.97351
# 14  Relájate y disfruta en HD del proceso de ensam...  2.90294
# 15  Como usar auto clicker para Roblox. Distintas ...  2.86387
# 16  La tecnología de innovación de los últimos año...        2
# 17  Hoy voy a compartir con uds. la forma de model...  2.94801
# 18  Relájate y disfruta en HD del proceso de ensam...  2.90975
# 19  Cómo construir un carro de LEGO. Hay muchas ma...  2.94745
# 20  Estudiantes de la Universidad Politécnica Sale...  2.91261
# 21  Cómo se fabrica un coche, en cuatro pasos. Rep...  2.77755
# 22  Mi padre es discapacitado 100% y esta en trami...  2.88553
# 23  Poco antes del patinaje ya la batería a duras ...  2.85467
# 24  Muy interesante la construcción y cuidado de u...  2.95274
# 25  Los carros que hayan sido seleccionados para c...  2.92617
# 26  Bueno, incluso bajo su perfil más complejo, el...  2.92826
# 27  Relájate y disfruta en HD del proceso de ensam...  2.90975
# 28  Sin duda el automóvil es una pieza clave en la...  2.91714
# 29  El SOAP, o Seguro Obligatorio de Accidentes Pe...  2.77283

# %%
#df.to_csv('participants_ext_2.csv', index=False)
