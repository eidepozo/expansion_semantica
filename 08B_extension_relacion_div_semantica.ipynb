# %% [markdown]
# @eidepozo

# %%
import pandas as pd

# %%
df1 = pd.read_csv('g1_modelB_pairs2.csv') # valor semantico de la palabra (3 modelos * 50 expansiones * 2 grupos de consultas)
df2 = pd.read_csv('g2_modelB_pairs2.csv') # junto a diversidad obtenida

# %%
df1
# Out:
#      similarity_w   sum_cos
# 0        0.998925  2.959553
# 1        0.998415  2.815409
# 2        0.998383  3.000000
# 3        0.998343  2.973554
# 4        0.998335  2.900182
# ..            ...       ...
# 595      0.761059  2.388183
# 596      0.761039  2.904004
# 597      0.760111  2.885397
# 598      0.760021  2.335392
# 599      0.759771  2.490666
#
# [600 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.scatterplot(ax=ax, data=df1, x="similarity_w", y="sum_cos", s=65, color='#009f75', alpha=0.85)
sns.scatterplot(ax=ax, data=df2, x="similarity_w", y="sum_cos", color='#ef4444', s=65, alpha=0.85)
plt.axhline(y=2.845, color ='g', label='2.845')
plt.axhline(y=2.905, color ='r', label='2.905')
plt.legend(labels=['2.845 (G1)', '2.905 (G2)', 'Group 1', 'Group 2'])
bottom, top = plt.ylim()
plt.ylabel("sum_cos")
#print(bottom, top)
plt.ylim(bottom=1.85, top= 3.4)
# Out:
# (1.85, 3.4)

# %%
df1.describe()
# Out:
#        similarity_w     sum_cos
# count    600.000000  600.000000
# mean       0.952074    2.826094
# std        0.085155    0.214905
# min        0.759771    1.357864
# 25%        0.994923    2.793196
# 50%        0.997349    2.909559
# 75%        0.997902    2.952404
# max        0.998925    3.000000

# %%
df2.describe()
# Out:
#        similarity_w     sum_cos
# count    350.000000  350.000000
# mean       0.990265    2.856040
# std        0.017846    0.196324
# min        0.933674    1.654231
# 25%        0.995131    2.826878
# 50%        0.997443    2.917462
# 75%        0.998198    2.969006
# max        0.999561    3.000000
